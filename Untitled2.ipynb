# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('customer.csv')

# %%
df.sample(5)
# Out:
#     age  gender   review education purchased
# 8    65  Female  Average        UG        No
# 1    68  Female     Poor        UG        No
# 16   59    Male     Poor        UG       Yes
# 43   27    Male     Poor        PG        No
# 11   74    Male     Good        UG       Yes

# %%
df=df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_test,y_test=train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=0.2)

# %%
X_train
# Out:
#      review education
# 27     Poor        PG
# 7      Poor    School
# 38     Good    School
# 9      Good        UG
# 37  Average        PG
# 30  Average        UG
# 2      Good        PG
# 4   Average        UG
# 14     Poor        PG
# 32  Average        UG
# 1      Poor        UG
# 47     Good        PG
# 19     Poor        PG
# 46     Poor        PG
# 15     Poor        UG
# 3      Good        PG
# 43     Poor        PG
# 5   Average    School
# 10     Good        UG
# 42     Good        PG
# 24  Average        PG
# 49     Good        UG
# 45     Poor        PG
# 23     Good    School
# 20  Average    School
# 21  Average        PG
# 44  Average        UG
# 18     Good    School
# 17     Poor        UG
# 13  Average    School
# 25     Good    School
# 41     Good        PG
# 8   Average        UG
# 33     Good        PG
# 16     Poor        UG
# 11     Good        UG
# 39     Poor        PG
# 35     Poor    School
# 48     Good        UG
# 28     Poor    School

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe=OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']])

# %%
oe.fit(X_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 oe.fit(X_train)
#
# File D:\Anaconda\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File D:\Anaconda\Lib\site-packages\sklearn\preprocessing\_encoders.py:1515, in OrdinalEncoder.fit(self, X, y)
#    1508     raise TypeError(
#    1509         "unknown_value should only be set when "
#    1510         "handle_unknown is 'use_encoded_value', "
#    1511         f"got {self.unknown_value}."
#    1512     )
#    1514 # `_fit` will only raise an error when `self.handle_unknown="error"`
# -> 1515 fit_results = self._fit(
#    1516     X,
#    1517     handle_unknown=self.handle_unknown,
#    1518     ensure_all_finite="allow-nan",
#    1519     return_and_ignore_missing_for_infrequent=True,
#    1520 )
#    1521 self._missing_indices = fit_results["missing_indices"]
#    1523 cardinalities = [len(categories) for categories in self.categories_]
#
# File D:\Anaconda\Lib\site-packages\sklearn\preprocessing\_encoders.py:118, in _BaseEncoder._fit(self, X, handle_unknown, ensure_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#     115 else:
#     116     Xi_dtype = Xi.dtype
# --> 118 cats = np.array(self.categories[i], dtype=Xi_dtype)
#     119 if (
#     120     cats.dtype == object
#     121     and isinstance(cats[0], bytes)
#     122     and Xi.dtype.kind != "S"
#     123 ):
#     124     msg = (
#     125         f"In column {i}, the predefined categories have type 'bytes'"
#     126         " which is incompatible with values of type"
#     127         f" '{type(Xi[0]).__name__}'."
#     128     )
#
# ValueError: could not convert string to float: 'Poor'

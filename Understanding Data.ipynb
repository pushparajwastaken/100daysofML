# %%
import pandas as pd

# %%
df=pd.read_csv('track_data_final.csv')

# %% [markdown]
# # 1.How big is the Data ?

# %%
df.shape
# Out:
# (8778, 15)

# %% [markdown]
# # 2.How does the data Look like?

# %%
df.head()
# Out:
#                  track_id                           track_name  track_number  \
# 0  6pymOcrCnMuCWdgGVTvUgP                                    3            57
# 1  2lWc1iJlz2NVcStV5fbtPG                               Clouds             1
# 2  1msEuwSBneBKpVCZQcFTsU  Forever & Always (Taylor’s Version)            11
# 3  7bcy34fBT2ap1L4bfPsl9q            I Didn't Change My Number             2
# 4  0GLfodYacy3BJE7AI3A8en                             Man Down             7
#
#    track_popularity  track_duration_ms  explicit     artist_name  \
# 0                61             213173     False  Britney Spears
# 1                67             158760     False           BUNT.
# 2                63             225328     False    Taylor Swift
# 3                72             158463      True   Billie Eilish
# 4                57             267013     False         Rihanna
#
#    artist_popularity  artist_followers      artist_genres  \
# 0               80.0        17755451.0            ['pop']
# 1               69.0          293734.0  ['stutter house']
# 2              100.0       145396321.0                 []
# 3               90.0       118692183.0                 []
# 4               90.0        68997177.0                 []
#
#                  album_id                   album_name album_release_date  \
# 0  325wcm5wMnlfjmKZ8PXIIn       The Singles Collection         2009-11-09
# 1  2ArRQNLxf9t0O0gvmG5Vsj                       Clouds         2023-01-13
# 2  4hDok0OAJd57SGIT8xuWJH  Fearless (Taylor's Version)         2021-04-09
# 3  0JGOiO34nwfUdDrD612dOp            Happier Than Ever         2021-07-30
# 4  5QG3tjE5L9F6O2vCAPph38                         Loud         2010-01-01
#
#    album_total_tracks   album_type
# 0                  58  compilation
# 1                   1       single
# 2                  26        album
# 3                  16        album
# 4                  13        album

# %%
df.sample(5) # 5 random rows
# Out:
#                     track_id                                track_name  \
# 3238  1ipnbmNWOpIRIVDWiZzNpV  Tangled - Kingdom Dance (Tavern Edition)
# 2338  5yuXdw2gb5bV4MXngcfvN6                           Why Do We Fall?
# 476   5JqZ3oqF00jkT81foAFvqg                 Prisoner (feat. Dua Lipa)
# 6351  6buHoQU9OTdbJrAuniVwGL                                Davy Jones
# 4541  3cwDSDzTiWr5H5xMQhQ6Mx                                   Du hast
#
#       track_number  track_popularity  track_duration_ms  explicit  \
# 3238             1                 0             138700     False
# 2338            11                 1             122920     False
# 476              1                 1             169333     False
# 6351             3                58             195240     False
# 4541             5                 2             234226     False
#
#              artist_name  artist_popularity  artist_followers  \
# 3238  Colm R. McGuinness               56.0          169882.0
# 2338         Hans Zimmer               77.0         4777574.0
# 476          Miley Cyrus               81.0        26558356.0
# 6351         Hans Zimmer               77.0         4780589.0
# 4541           Rammstein               77.0        11810806.0
#
#                                           artist_genres  \
# 3238                         ['sea shanties', 'celtic']
# 2338                                     ['soundtrack']
# 476                                                  []
# 6351                                     ['soundtrack']
# 4541  ['industrial metal', 'metal', 'industrial rock...
#
#                     album_id  \
# 3238  2RyyO2q3J5nPrkoBWWA64m
# 2338  3sGDniFo4e5r0bwmSL2upZ
# 476   3hUh17FzYZwwZyNjU9B3vL
# 6351  5eQEdvd6pq0uo2pQa56aUH
# 4541  6f4dhaPfZqf2JXewAvE4gq
#
#                                              album_name album_release_date  \
# 3238           Tangled - Kingdom Dance (Tavern Edition)         2022-02-17
# 2338                              The Dark Knight Rises         2012-08-29
# 476                           Prisoner (feat. Dua Lipa)         2020-11-20
# 6351  Pirates of the Caribbean: Dead Man's Chest (Or...         2006-01-01
# 4541                                          Sehnsucht         1997-08-25
#
#       album_total_tracks   album_type
# 3238                   1       single
# 2338                  15        album
# 476                    1       single
# 6351                  12  compilation
# 4541                  11        album

# %% [markdown]
# # 3.What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8778 entries, 0 to 8777
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8778 non-null   object
#  1   track_name          8776 non-null   object
#  2   track_number        8778 non-null   int64
#  3   track_popularity    8778 non-null   int64
#  4   track_duration_ms   8778 non-null   int64
#  5   explicit            8778 non-null   bool
#  6   artist_name         8774 non-null   object
#  7   artist_popularity   8774 non-null   float64
#  8   artist_followers    8774 non-null   float64
#  9   artist_genres       8774 non-null   object
#  10  album_id            8778 non-null   object
#  11  album_name          8776 non-null   object
#  12  album_release_date  8778 non-null   object
#  13  album_total_tracks  8778 non-null   int64
#  14  album_type          8778 non-null   object
# dtypes: bool(1), float64(2), int64(4), object(8)
# memory usage: 968.8+ KB

# %% [markdown]
# # 4.Are there any missing values?

# %%
df.isnull().sum()
# Out:
# track_id              0
# track_name            2
# track_number          0
# track_popularity      0
# track_duration_ms     0
# explicit              0
# artist_name           4
# artist_popularity     4
# artist_followers      4
# artist_genres         4
# album_id              0
# album_name            2
# album_release_date    0
# album_total_tracks    0
# album_type            0
# dtype: int64

# %% [markdown]
# # 5.How does the data look mathematically?

# %%
df.describe()
# Out:
#        track_number  track_popularity  track_duration_ms  artist_popularity  \
# count   8778.000000       8778.000000        8778.000000        8774.000000
# mean       5.749487         52.232855      210157.791866          69.954981
# std        6.017938         24.075221       63326.841454          19.532783
# min        1.000000          0.000000           0.000000           0.000000
# 25%        1.000000         39.000000      173921.250000          60.000000
# 50%        4.000000         58.000000      207276.000000          74.000000
# 75%        9.000000         71.000000      239693.250000          84.000000
# max      102.000000        100.000000      811077.000000         100.000000
#
#        artist_followers  album_total_tracks
# count      8.774000e+03         8778.000000
# mean       2.435487e+07           13.779790
# std        3.813769e+07           11.797943
# min        0.000000e+00            1.000000
# 25%        5.152768e+05            6.000000
# 50%        6.272266e+06           13.000000
# 75%        3.055055e+07           17.000000
# max        1.455421e+08          181.000000

# %% [markdown]
# # 6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 7.How is the correlation between cols?

# %%
df.corr(numeric_only=True)
# Out:
#                     track_number  track_popularity  track_duration_ms  \
# track_number            1.000000         -0.024465           0.070455
# track_popularity       -0.024465          1.000000           0.107116
# track_duration_ms       0.070455          0.107116           1.000000
# explicit               -0.009311          0.126507           0.009494
# artist_popularity       0.188944          0.455739           0.212325
# artist_followers        0.221637          0.226570           0.175630
# album_total_tracks      0.518550         -0.047275           0.067941
#
#                     explicit  artist_popularity  artist_followers  \
# track_number       -0.009311           0.188944          0.221637
# track_popularity    0.126507           0.455739          0.226570
# track_duration_ms   0.009494           0.212325          0.175630
# explicit            1.000000           0.172190          0.102331
# artist_popularity   0.172190           1.000000          0.637667
# artist_followers    0.102331           0.637667          1.000000
# album_total_tracks -0.058256           0.200468          0.186392
#
#                     album_total_tracks
# track_number                  0.518550
# track_popularity             -0.047275
# track_duration_ms             0.067941
# explicit                     -0.058256
# artist_popularity             0.200468
# artist_followers              0.186392
# album_total_tracks            1.000000

# %%
print("Introduction to Pandas")
# Out:
# Introduction to Pandas

# %% [markdown]
# There are 2 key structures in Pandas:
# 1. Series
# 2. Data Frame

# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %% [markdown]
# Series is a labelled array in Pandas

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df=pd.DataFrame({"names":["Lavanya", "Pushparaj"], "marks":[100,99]})

# %%
df
# Out:
#        names  marks
# 0    Lavanya    100
# 1  Pushparaj     99

# %%
df=pd.read_csv("spotify_data clean.csv")

# %%
df
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
df.tail()
# Out:
#                     track_id          track_name  track_number  \
# 8577  0AQquaENerGps8BQmbPw14            Big Iron             1
# 8578  4f8hBeMXMvssn6HtFAtblo             El Paso            10
# 8579  0Vy7wsXNFrbNc6UTWoScnM    Over the Rainbow             5
# 8580  760clbeDBWmBsBLbszWuNZ           I'm A Man             2
# 8581  61GEP8lryEfcuEgBMbRmNi  Alone And Forsaken            11
#
#       track_popularity  explicit    artist_name  artist_popularity  \
# 8577                71     False  Marty Robbins                 60
# 8578                64     False  Marty Robbins                 61
# 8579                 8     False    The Mystics                 27
# 8580                55     False     Bo Diddley                 44
# 8581                45     False  Hank Williams                 55
#
#       artist_followers                                      artist_genres  \
# 8577            626733                    classic country, outlaw country
# ...

# %%
df.head()
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity  explicit artist_name  artist_popularity  \
# 0             4                 0      True       Diplo                 77
# 1             1                 0      True    Yelawolf                 64
# 2             1                 4      True   Riff Raff                 48
# 3             8                30      True       Diplo                 77
# 4             2                 0      True     Rumelis                 48
#
#    artist_followers                      artist_genres  \
# ...

# %%
df.describe()
# Out:
#        track_number  track_popularity  artist_popularity  artist_followers  \
# count   8582.000000       8582.000000        8582.000000      8.582000e+03
# mean       5.772547         52.356211          69.730016      2.403472e+07
# std        6.052792         23.816076          19.645979      3.803180e+07
# min        1.000000          0.000000           0.000000      0.000000e+00
# 25%        1.000000         39.000000          60.000000      4.623200e+05
# 50%        4.000000         58.000000          74.000000      6.105547e+06
# 75%        9.000000         71.000000          84.000000      2.725255e+07
# max      102.000000         99.000000         100.000000      1.455421e+08
#
#        album_total_tracks  track_duration_min
# count         8582.000000         8582.000000
# mean            13.789443            3.492805
# std             11.887131            1.057970
# min              1.000000            0.070000
# 25%              6.000000            2.880000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8582 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8582 non-null   object
#  1   track_name          8582 non-null   object
#  2   track_number        8582 non-null   int64
#  3   track_popularity    8582 non-null   int64
#  4   explicit            8582 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8582 non-null   int64
#  7   artist_followers    8582 non-null   int64
#  8   artist_genres       5221 non-null   object
#  9   album_id            8582 non-null   object
#  10  album_name          8582 non-null   object
#  11  album_release_date  8582 non-null   object
#  12  album_total_tracks  8582 non-null   int64
#  13  album_type          8582 non-null   object
#  14  track_duration_min  8582 non-null   float64
# ...

# %% [markdown]
# # Data Selection

# %%
type(df["album_id"])
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.rename(columns={"explicit":"exp"}).head()
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity   exp artist_name  artist_popularity  \
# 0             4                 0  True       Diplo               77.0
# 1             1                 0  True    Yelawolf               64.0
# 2             1                 4  True   Riff Raff               48.0
# 3             8                30  True       Diplo               77.0
# 4             2                 0  True     Rumelis               48.0
#
#    artist_followers                      artist_genres  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8582 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8582 non-null   object
#  1   track_name          8582 non-null   object
#  2   track_number        8582 non-null   int64
#  3   track_popularity    8582 non-null   int64
#  4   explicit            8582 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8582 non-null   int64
#  7   artist_followers    8582 non-null   int64
#  8   artist_genres       5221 non-null   object
#  9   album_id            8582 non-null   object
#  10  album_name          8582 non-null   object
#  11  album_release_date  8582 non-null   object
#  12  album_total_tracks  8582 non-null   int64
#  13  album_type          8582 non-null   object
#  14  track_duration_min  8582 non-null   float64
# ...

# %%
df["artist_popularity"]=df["artist_popularity"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8582 entries, 0 to 8581
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   track_id            8582 non-null   object
#  1   track_name          8582 non-null   object
#  2   track_number        8582 non-null   int64
#  3   track_popularity    8582 non-null   int64
#  4   explicit            8582 non-null   bool
#  5   artist_name         8579 non-null   object
#  6   artist_popularity   8582 non-null   float64
#  7   artist_followers    8582 non-null   int64
#  8   artist_genres       5221 non-null   object
#  9   album_id            8582 non-null   object
#  10  album_name          8582 non-null   object
#  11  album_release_date  8582 non-null   object
#  12  album_total_tracks  8582 non-null   int64
#  13  album_type          8582 non-null   object
#  14  track_duration_min  8582 non-null   float64
# ...

# %%
def Fx(a):
    return a+1
df["zeroes+1"]=df["zeroes"].apply(Fx)

# %%
df.head()
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity  explicit artist_name  artist_popularity  \
# 0             4                 0      True       Diplo               77.0
# 1             1                 0      True    Yelawolf               64.0
# 2             1                 4      True   Riff Raff               48.0
# 3             8                30      True       Diplo               77.0
# 4             2                 0      True     Rumelis               48.0
#
#    artist_followers                      artist_genres  \
# ...

# %%
df.shape
# Out:
# (8582, 17)

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'track_number', 'track_popularity',
#        'explicit', 'artist_name', 'artist_popularity', 'artist_followers',
#        'artist_genres', 'album_id', 'album_name', 'album_release_date',
#        'album_total_tracks', 'album_type', 'track_duration_min', 'zeroes',
#        'zeroes+1'],
#       dtype='object')

# %%
df.dtypes
# Out:
# track_id               object
# track_name             object
# track_number            int64
# track_popularity        int64
# explicit                 bool
# artist_name            object
# artist_popularity     float64
# artist_followers        int64
# artist_genres          object
# album_id               object
# album_name             object
# album_release_date     object
# album_total_tracks      int64
# album_type             object
# track_duration_min    float64
# zeroes                  int64
# zeroes+1                int64
# dtype: object

# %%
df.loc[100]
# Out:
# track_id                 62HoDY1Km6lm47haFpUn9c
# track_name                      Eldest Daughter
# track_number                                  5
# track_popularity                             92
# explicit                                   True
# artist_name                        Taylor Swift
# artist_popularity                         100.0
# artist_followers                      145396321
# artist_genres         country, pop, indie, folk
# album_id                 4a6NzYL1YHRUgx9e3YZI6I
# album_name               The Life of a Showgirl
# album_release_date                    10/3/2025
# album_total_tracks                           12
# album_type                                album
# track_duration_min                          4.1
# zeroes                                        0
# zeroes+1                                      1
# Name: 100, dtype: object

# %%
df.iloc[100]
# Out:
# track_id                 62HoDY1Km6lm47haFpUn9c
# track_name                      Eldest Daughter
# track_number                                  5
# track_popularity                             92
# explicit                                   True
# artist_name                        Taylor Swift
# artist_popularity                         100.0
# artist_followers                      145396321
# artist_genres         country, pop, indie, folk
# album_id                 4a6NzYL1YHRUgx9e3YZI6I
# album_name               The Life of a Showgirl
# album_release_date                    10/3/2025
# album_total_tracks                           12
# album_type                                album
# track_duration_min                          4.1
# zeroes                                        0
# zeroes+1                                      1
# Name: 100, dtype: object

# %%
df.fillna(0)
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
df.dropna()
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# 5     4ccpCcZYseq8VrPMK1EDs0                                            BLEED
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
df.drop_duplicates()
# Out:
#                     track_id                                       track_name  \
# 0     3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1     1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2     7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3     67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4     15xptTfRBrjsppW0INUZjf                            ride me like a harley
# ...                      ...                                              ...
# 8577  0AQquaENerGps8BQmbPw14                                         Big Iron
# 8578  4f8hBeMXMvssn6HtFAtblo                                          El Paso
# 8579  0Vy7wsXNFrbNc6UTWoScnM                                 Over the Rainbow
# 8580  760clbeDBWmBsBLbszWuNZ                                        I'm A Man
# 8581  61GEP8lryEfcuEgBMbRmNi                               Alone And Forsaken
#
# ...

# %%
df['track_details'] = (
    df['track_name'].astype(str) 
    + " - " 
    + df['track_duration_min'].astype(str) 
    + " - " 
    + df['artist_name'].astype(str)
)

# %%
df.head()
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity  explicit artist_name  artist_popularity  \
# 0             4                 0      True       Diplo               77.0
# 1             1                 0      True    Yelawolf               64.0
# 2             1                 4      True   Riff Raff               48.0
# 3             8                30      True       Diplo               77.0
# 4             2                 0      True     Rumelis               48.0
#
#    artist_followers                      artist_genres  \
# ...

# %%
df.groupby('artist_name')['track_duration_min'].agg(['mean', 'max', 'min', 'count'])
# Out:
#                   mean   max   min  count
# artist_name
# $uicideboy$       2.62  3.39  1.85      2
# 'Ery Noice        1.16  1.16  1.16      1
# (((())))          2.47  2.47  2.47      1
# *NSYNC            3.34  3.34  3.34      1
# -                 1.73  1.73  1.73      1
# ...                ...   ...   ...    ...
# 攬佬SKAI ISYOURGOD  2.51  2.51  2.51      1
# 時瀬高等学校箏曲部         7.98  7.98  7.98      1
# 桑原まこ              2.08  2.08  2.08      1
# 梶浦 由記             1.89  1.89  1.89      1
# 藤澤慶昌              2.26  2.53  1.99      2
#
# [2547 rows x 4 columns]

# %%
df.head()
# Out:
#                  track_id                                       track_name  \
# 0  3EJS5LyekDim1Tf5rBFmZl                    Trippy Mane (ft. Project Pat)
# 1  1oQW6G2ZiwMuHqlPpP27DB                                             OMG!
# 2  7mdkjzoIYlf1rx9EtBpGmU                                      Hard 2 Find
# 3  67rW0Zl7oB3qEpD5YWWE5w  Still Get Like That (ft. Project Pat & Starrah)
# 4  15xptTfRBrjsppW0INUZjf                            ride me like a harley
#
#    track_number  track_popularity  explicit artist_name  artist_popularity  \
# 0             4                 0      True       Diplo               77.0
# 1             1                 0      True    Yelawolf               64.0
# 2             1                 4      True   Riff Raff               48.0
# 3             8                30      True       Diplo               77.0
# 4             2                 0      True     Rumelis               48.0
#
#    artist_followers                      artist_genres  \
# ...

# %%
df.groupby('artist_name', as_index=False)['track_duration_min'].mean()
# Out:
#            artist_name  track_duration_min
# 0          $uicideboy$                2.62
# 1           'Ery Noice                1.16
# 2             (((())))                2.47
# 3               *NSYNC                3.34
# 4                    -                1.73
# ...                ...                 ...
# 2542  攬佬SKAI ISYOURGOD                2.51
# 2543         時瀬高等学校箏曲部                7.98
# 2544              桑原まこ                2.08
# 2545             梶浦 由記                1.89
# 2546              藤澤慶昌                2.26
#
# [2547 rows x 2 columns]

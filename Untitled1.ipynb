# %%
import pandas as pd

# %%
df=pd.read_csv('track_data_final.csv')

# %% [markdown]
# # Opening a CSV file from an URL

# %%
import requests
from io import StringIO

# %%
# SEP PARAMETERS for tsv
# pd.read_csv('movies',sep='\t')

# %%
# Index PARAMETERS to use a particular column for indexing
# pd.read_csv('movies',index_col="id")

# %%
# Header PARAMETERS to convert a column to column header
# pd.read_csv('movies',header=1)

# %%
# Use Cols parameter to use particular columns of a dataset
# pd.read_csv('movies',usecols=['name','release_year','collection'])

# %%
# Squeeze paramters when we only wish to use only one column
# pd.read_csv('movies',squeeze=True,useCols=['director'])

# %%
#skiprows/nrows
#skiprows=[0,2]

# %%
#encoding parameter
#generally utf-8
#encoding='latin-1'

# %%
# skip bad lines
#error_bad_lines=false
#parse error
#removes the lines which give error

# %%
# dtypes Parameter
#dtype='col_name':int

# %%
    # Handl

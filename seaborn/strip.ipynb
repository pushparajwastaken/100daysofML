# %% [markdown]
# # Strip Plots

# %%
import seaborn as sns

# %%
data=sns.load_dataset("tips")

# %%
sns.catplot(x="day",y="total_bill",kind="strip",hue="sex",data=data)

# %%
sns.catplot(x="day",y="tip",kind="swarm",hue="sex",data=data)
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import pandas as pd
import requests 
from bs4 import BeautifulSoup
import numpy as np

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get("https://www.imdb.com/search/title/?moviemeter=,10", headers=headers).text

# %%
soup=BeautifulSoup(webpage,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <script>
#    if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1764409210116);
#         }
#     })
#   </script>
#   <title>
#    Advanced search
#   </title>
#   <meta content="" data-id="main" name="description"/>
#   <meta content="0cadf7898134e79b" name="google-site-verification"/>
# ...

# %%
soup.find_all('h1')[0].text
# Out:
# 'Advanced search'

# %%
soup.find_all('h3')
# Out:
# [<h3 class="ipc-title__text ipc-title__text--reduced">1. Pluribus</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">2. The Beast in Me</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">3. Stranger Things</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">4. Frankenstein</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">5. Wicked: For Good</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">6. One Battle After Another</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">7. Train Dreams</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">8. IT: Welcome to Derry</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">9. Wicked</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">10. All Her Fault</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">11. A Man on the Inside</h3>,
#  <h3 class="ipc-title__text ipc-title__text--reduced">12. The Running Man</h3>,
# ...

# %%
for i in soup.find_all('h3'):
    print(i.text.strip())
# Out:
# 1. Pluribus
# 2. The Beast in Me
# 3. Stranger Things
# 4. Frankenstein
# 5. Wicked: For Good
# 6. One Battle After Another
# 7. Train Dreams
# 8. IT: Welcome to Derry
# 9. Wicked
# 10. All Her Fault
# 11. A Man on the Inside
# 12. The Running Man
# 13. Landman
# 14. After the Hunt
# 15. The Hunger Games: Sunrise on the Reaping
# 16. Now You See Me: Now You Don't
# 17. Predator: Badlands
# 18. Absentia
# 19. The Family Plan 2
# 20. One Punch Man: Wanpanman
# Recently viewed

# %%
for i in soup.find_all('span',class_='ipc-rating-star--rating'):
    print(i.text.strip())
# Out:
# 8.5
# 7.5
# 8.6
# 7.5
# 7.1
# 8.0
# 7.6
# 7.7
# 7.4
# 7.6
# 7.6
# 6.7
# 8.2
# 5.9
# 6.3
# 7.5
# 7.2
# 5.6
# 8.6

# %%
for i in soup.find_all('div',class_='ipc-html-content-inner-div'):
    print(i.text.strip())
# Out:
# In a world overtaken by a mysterious wave of forced happiness, Carol Sturka, one of the few immune, must uncover what's really going on - and save humanity from its own bliss.
# Author Aggie Wiggs, grieving the loss of her son, finds new purpose unraveling the mystery behind neighbor Nile Jarvis' vanished wife and his suspicious dealings.
# In 1980s Indiana, a group of young friends witness supernatural forces and secret government exploits. As they search for answers, the children unravel a series of extraordinary mysteries.
# Dr. Victor Frankenstein, a brilliant but egotistical scientist, brings a creature to life in a monstrous experiment that ultimately leads to the undoing of both the creator and his tragic creation.
# Elphaba, the future Wicked Witch of the West and her relationship with Glinda, the Good Witch of the North. The second of a two-part feature film adaptation of the Broadway musical.
# ...

# %%
 soup.find_all('div',class_='ipc-html-content-inner-div')[0].text
# Out:
# "In a world overtaken by a mysterious wave of forced happiness, Carol Sturka, one of the few immune, must uncover what's really going on - and save humanity from its own bliss."

# %%
 soup.find_all('span',class_='sc-b4f120f6-4')[0]
# Out:
# <span class="sc-b4f120f6-4 eLLPMk dli-title-type-data">TV Series</span>

# %%
series=soup.find_all('div', class_='ipc-metadata-list-summary-item__tc')

# %%
len(series)
# Out:
# 10

# %%
name=[]
rating=[]
desc=[]
for i in series:
    name.append(i.find('h3').text)
    rating.append(i.find('span',class_='ipc-rating-star--rating').text.strip())
    desc.append(i.find('div',class_='ipc-html-content-inner-div').text)
d={'name':name,'rating':rating,'description':desc}
df=pd.DataFrame(d)
df.style.hide(axis="index")
df
# Out:
#                           name rating  \
# 0                  1. Pluribus    8.5
# 1           2. The Beast in Me    7.5
# 2           3. Stranger Things    8.6
# 3              4. Frankenstein    7.5
# 4          5. Wicked: For Good    7.1
# 5  6. One Battle After Another    8.0
# 6              7. Train Dreams    7.6
# 7      8. IT: Welcome to Derry    7.7
# 8                    9. Wicked    7.4
# 9            10. All Her Fault    7.6
#
#                                          description
# 0  In a world overtaken by a mysterious wave of f...
# 1  Author Aggie Wiggs, grieving the loss of her s...
# 2  In 1980s Indiana, a group of young friends wit...
# 3  Dr. Victor Frankenstein, a brilliant but egoti...
# 4  Elphaba, the future Wicked Witch of the West a...
# 5  When their evil enemy resurfaces after 16 year...
# 6  Based on Denis Johnson's beloved novella, Trai...
# 7  In 1962, a couple with their son move to Derry...
# 8  Elphaba, a young woman ridiculed for her green...
# ...

# %%
name
# Out:
# ['1. Pluribus',
#  '2. The Beast in Me',
#  '3. Stranger Things',
#  '4. Frankenstein',
#  '5. Wicked: For Good',
#  '6. One Battle After Another',
#  '7. Train Dreams',
#  '8. IT: Welcome to Derry',
#  '9. Wicked',
#  '10. All Her Fault',
#  '11. A Man on the Inside',
#  '12. The Running Man',
#  '13. Landman',
#  '14. After the Hunt',
#  '15. The Hunger Games: Sunrise on the Reaping',
#  "16. Now You See Me: Now You Don't",
#  '17. Predator: Badlands',
#  '18. Absentia',
#  '19. The Family Plan 2',
#  '20. One Punch Man: Wanpanman']

# %%
rating
# Out:
# ['8.5', '7.5', '8.6', '7.5', '7.1', '8.0', '7.6', '7.7', '7.4', '7.6']

# %%
desc
# Out:
# ["In a world overtaken by a mysterious wave of forced happiness, Carol Sturka, one of the few immune, must uncover what's really going on - and save humanity from its own bliss.",
#  "Author Aggie Wiggs, grieving the loss of her son, finds new purpose unraveling the mystery behind neighbor Nile Jarvis' vanished wife and his suspicious dealings.",
#  'In 1980s Indiana, a group of young friends witness supernatural forces and secret government exploits. As they search for answers, the children unravel a series of extraordinary mysteries.',
#  'Dr. Victor Frankenstein, a brilliant but egotistical scientist, brings a creature to life in a monstrous experiment that ultimately leads to the undoing of both the creator and his tragic creation.',
#  'Elphaba, the future Wicked Witch of the West and her relationship with Glinda, the Good Witch of the North. The second of a two-part feature film adaptation of the Broadway musical.',
# ...
